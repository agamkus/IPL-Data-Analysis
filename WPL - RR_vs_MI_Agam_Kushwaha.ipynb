# %% [markdown]
# ### Importing Library:

# %%
import pandas as pd

# %% [markdown]
# ### Loading "Matches" Dataset:

# %%
data1 = pd.read_csv("matches.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data2 = pd.read_csv('deliveries.csv')
data1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ### Filtering RR and MI matches only:

# %%
rr_mi = data1.loc[((data1['team1'] == 'Mumbai Indians') & (data1['team2'] == 'Rajasthan Royals') | (data1['team1'] == 'Rajasthan Royals') & (data1['team2'] == 'Mumbai Indians'))]
rr_mi.head()
# Out:
#       id  season    city        date             team1             team2  \
# 85    86    2008  Mumbai  2008-05-07  Rajasthan Royals    Mumbai Indians
# 112  113    2008  Jaipur  2008-05-26    Mumbai Indians  Rajasthan Royals
# 159  160    2009  Durban  2009-05-14  Rajasthan Royals    Mumbai Indians
# 175  176    2010  Mumbai  2010-03-13    Mumbai Indians  Rajasthan Royals
# 218  219    2010  Jaipur  2010-04-11    Mumbai Indians  Rajasthan Royals
#
#           toss_winner toss_decision  result  dl_applied            winner  \
# 85     Mumbai Indians         field  normal           0    Mumbai Indians
# 112  Rajasthan Royals         field  normal           0  Rajasthan Royals
# 159  Rajasthan Royals           bat  normal           0  Rajasthan Royals
# 175    Mumbai Indians           bat  normal           0    Mumbai Indians
# 218  Rajasthan Royals         field  normal           0    Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match                       venue  \
# ...

# %% [markdown]
# ### Question 1: Who will win the match?

# %% [markdown]
# #### Solution: Checking counts of winner:

# %%
rr_mi['winner'].value_counts()/rr_mi.shape[0] * 100
# Out:
# Rajasthan Royals    50.0
# Mumbai Indians      50.0
# Name: winner, dtype: float64

# %% [markdown]
# **Answer:** As per the above counts, RR and MI both won 10-10 matches.

# %% [markdown]
# ## Question 2: How balls will Rashid Khan tak to get his first wicket?

# %% [markdown]
# ### Loading "Deliveries" dataset:

# %%
data2 = pd.read_csv("deliveries.csv")
data2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0          0         0
# 1     2  DA Warner    S Dhawan  TS Mills              0          0         0
# 2     3  DA Warner    S Dhawan  TS Mills              0          0         0
# 3     4  DA Warner    S Dhawan  TS Mills              0          0         0
# 4     5  DA Warner    S Dhawan  TS Mills              0          2         0
#
# ...

# %% [markdown]
# #### Solution: Filtering data with Rashid Khan as bowler:

# %%
rashid_wickets = data2.loc[(data2['bowler'] == "Rashid Khan")]
rashid_wicket
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 157            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 158            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 159            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 161            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 162            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 169            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 170            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 171            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 172            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 173            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...

# %% [markdown]
# #### Getting mean of the wide runs match wise:

# %%
wide = pd.DataFrame(srh_csk_wide.groupby('match_id')['wide_runs'].sum())
wide['wide_runs'].mean()
# Out:
# 7.7727272727272725

# %% [markdown]
# **Answer:** Average wide runs in each match is 7.77. So, I would prdict that around 8 wides will be bowled in this match.

# %% [markdown]
# ### Filtering SRH and CSK matches where batting team is SRH and bowling team is CSK:

# %%
srh_csk_bowl = data2.loc[(data2['batting_team'] == "Sunrisers Hyderabad") & (data2['bowling_team'] == "Chennai Super Kings")]
srh_csk_bowl.head(20)
# Out:
#        match_id  inning         batting_team         bowling_team  over  ball  \
# 97960       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     1
# 97961       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     2
# 97962       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     3
# 97963       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     4
# 97964       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     5
# 97965       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     6
# 97966       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     1
# 97967       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     2
# 97968       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     3
# 97969       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     4
# 97970       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     5
# ...

# %% [markdown]
# ## Question 3: Which individual batsman in the match will have the best (number of runs scored of boundaries : (total runs scored) ratio?

# %% [markdown]
# #### Solution: Observing match wise David Warner's dismissal kind:

# %%
david_dismissal = pd.DataFrame(data2[data2['batsman'] == 'DA Warner'].groupby('dismissal_kind')['player_dismissed'].count())
david_dismissal = david_dismissal.rename({'player_dismissed' : 'Dismissal Kind'}, axis = 1)
david_dismissal
# Out:
#                    Dismissal Kind
# dismissal_kind
# bowled                         23
# caught                         69
# caught and bowled               2
# hit wicket                      1
# lbw                             4
# run out                        10
# stumped                         5

# %% [markdown]
# **Answer:** David Warner get out by caught mostly.

# %% [markdown]
# ## Question 5: How many no-balls will be bowled in the match?

# %% [markdown]
# #### Solution: Filtering data with SRH and RR Matches and where there is run on no-ball:

# %%
wickets_per_match = csk_wickets.groupby('match_id')['player_dismissed'].count()
wickets_per_match = pd.DataFrame(wickets_per_match)
wickets_per_match
# Out:
#           player_dismissed
# match_id
# 414                      5
# 435                      3
# 474                      5
# 507                      3
# 521                      4
# 551                      6
# 7913                     3
# 7939                     2
# 7950                     8
# 7953                     2
# 11324                    5
# 11332                    4

# %% [markdown]
# #### Average wickets per match:

# %%
avg_wic = wickets_per_match['player_dismissed'].mean()
avg_wic
# Out:
# 4.166666666666667

# %%
rr_srh_nb = data2.loc[((data2['batting_team'] == "Sunrisers Hyderabad") & (data2['bowling_team'] == "Rajasthan Royals") | (data2['batting_team'] == "Rajasthan Royals") & (data2['bowling_team'] == "Sunrisers Hyderabad")) & (data2['noball_runs'] != 0)]
rr_srh_nb = pd.DataFrame(rr_srh_nb.groupby('match_id')['noball_runs'].count())
rr_srh_nb
# Out:
#           noball_runs
# match_id
# 529                 1
# 7897                1
# 11144               1

# %% [markdown]
# **Answer:** We see that on an average 1 no ball was bowled between RR and SRH match.
