# %% [markdown]
# ### Importing Library:

# %%
import pandas as pd

# %% [markdown]
# ### Loading "Matches" Dataset:

# %%
data1 = pd.read_csv("matches.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ### Filtering KKR and CSK matches only:

# %%
csk_kkr = data1.loc[((data1['team1'] == 'Chennai Super Kings') & (data1['team2'] == 'Kolkata Knight Riders') | (data1['team1'] == 'Kolkata Knight Riders') & (data1['team2'] == 'Chennai Super Kings'))]
csk_kkr.head(10)
# Out:
#       id  season       city        date                  team1  \
# 70    71    2008    Chennai  2008-04-26  Kolkata Knight Riders
# 102  103    2008    Kolkata  2008-05-18  Kolkata Knight Riders
# 165  166    2009  Centurion  2009-05-18    Chennai Super Kings
# 181  182    2010    Kolkata  2010-03-16    Chennai Super Kings
# 221  222    2010    Chennai  2010-04-13  Kolkata Knight Riders
# 234  235    2011    Chennai  2011-04-08    Chennai Super Kings
# 280  281    2011    Kolkata  2011-05-07    Chennai Super Kings
# 346  347    2012    Chennai  2012-04-30    Chennai Super Kings
# 367  368    2012    Kolkata  2012-05-14  Kolkata Knight Riders
# 380  381    2012    Chennai  2012-05-27    Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# 70     Chennai Super Kings  Kolkata Knight Riders           bat  normal
# 102    Chennai Super Kings  Kolkata Knight Riders           bat  normal
# ...

# %% [markdown]
# ## Question 1: Who will win the match?

# %% [markdown]
# #### Solution: Checking counts of winner:

# %%
csk_kkr['winner'].value_counts()/csk_kkr.shape[0] * 100
# Out:
# Chennai Super Kings      65.0
# Kolkata Knight Riders    35.0
# Name: winner, dtype: float64

# %% [markdown]
# **Answer:** As per the above analysis, winning percentage of CSK is **65** over KKR.

# %% [markdown]
# ## Question 2:

# %% [markdown]
# ### Loading "Deliveries" dataset:

# %%
data2 = pd.read_csv("deliveries.csv")
data2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0          0         0
# 1     2  DA Warner    S Dhawan  TS Mills              0          0         0
# 2     3  DA Warner    S Dhawan  TS Mills              0          0         0
# 3     4  DA Warner    S Dhawan  TS Mills              0          0         0
# 4     5  DA Warner    S Dhawan  TS Mills              0          2         0
#
# ...

# %%
csk_runs = data2.loc[(data2['batting_team'] == "Chennai Super Kings") & (data2['bowling_team'] == "Kolkata Knight Riders")]
csk_runs = pd.DataFrame(csk_runs.groupby('match_id')['total_runs'].sum())
csk_runs
# Out:
#           total_runs
# match_id
# 71               152
# 103               55
# 166              188
# 182              164
# 222              143
# 235              153
# 281              114
# 347              139
# 368              160
# 381              190
# 406              124
# 418              200
# 478              148
# 504              154
# 527              165
# 547              134
# 7898             212
# 7926             184
# 11314            119
# 11320            164

# %% [markdown]
# ### Average CSK runs:

# %%
avg_csk_runs = csk_runs['total_runs'].mean()
avg_csk_runs
# Out:
# 153.1

# %% [markdown]
# ## Question 3:

# %%
deepak_balls = data2.loc[data2['bowler'] == 'DL Chahar']
deepak_balls = pd.DataFrame(deepak_balls.groupby('match_id')['ball'].count())
deepak_balls
# Out:
#           ball
# match_id
# 2           12
# 9           20
# 33          12
# 625         12
# 629         21
# 7894        18
# 7898         7
# 7905        19
# 7910        28
# 7913        24
# 7917        12
# 7920        14
# 7939        27
# 7945        20
# 7949        27
# 7950        26
# 7953        26
# 11137       25
# 11141       25
# 11148       25
# 11151       18
# 11309       27
# 11314       28
# 11316       24
# 11320       24
# 11324       18
# 11330       25
# 11332       26
# 11335       25
# 11341       18
# 11346       24
# 11412       21
# 11414       25
# 11415       25

# %% [markdown]
# ## Question 4: How many balls will CSK take to score their 100 runs?

# %%
boundary = data2.loc[((data2['batting_team'] == "Chennai Super Kings") & (data2['bowling_team'] == "Kolkata Knight Riders") | (data2['batting_team'] == "Kolkata Knight Riders") & (data2['bowling_team'] == "Chennai Super Kings"))]
boundary = boundary.loc[(boundary['total_runs'] >=4) & (boundary['total_runs'] <= 7)]
boundary = pd.DataFrame(boundary.groupby('match_id')['over'].count()/6)
boundary
# Out:
#               over
# match_id
# 71        6.166667
# 103       4.333333
# 166       8.333333
# 182       5.666667
# 222       6.500000
# 235       6.000000
# 281       2.500000
# 347       3.666667
# 368       6.833333
# 381       7.500000
# 406       4.500000
# 418       8.833333
# 478       5.333333
# 504       6.500000
# 527       7.666667
# 547       5.000000
# 7898      8.666667
# 7926      8.500000
# 11314     4.333333
# 11320     7.666667

# %% [markdown]
# ### Avg Overs:

# %%
boundary['over'].mean()
# Out:
# 6.225

# %% [markdown]
# ## Question 5: How many no-balls will be bowled in the match?

# %% [markdown]
# #### Solution: Filtering data with CSK and Delhi Matches:

# %%
csk_kkr_nb = data2.loc[((data2['batting_team'] == "Chennai Super Kings") & (data2['bowling_team'] == "Kolkata Knight Riders") | (data2['batting_team'] == "Kolkata Knight Riders") & (data2['bowling_team'] == "Chennai Super Kings"))]
csk_kkr_nb = pd.DataFrame(csk_dc_nb.groupby('match_id')['noball_runs'].sum())
csk_kkr_nb
# Out:
#           noball_runs
# match_id
# 71                  3
# 103                 1
# 166                 1
# 182                 0
# 222                 0
# 235                 0
# 281                 0
# 347                 1
# 368                 0
# 381                 3
# 406                 0
# 418                 1
# 478                 2
# 504                 1
# 527                 0
# 547                 0
# 7898                1
# 7926                0
# 11314               2
# 11320               0

# %% [markdown]
# #### Getting mean of the no-ball runs match wise:

# %%
avg_nb = csk_kkr_nb['noball_runs'].mean()
avg_nb
# Out:
# 0.8

# %% [markdown]
# **Answer:** Average no-ball run in each match is very less 0.81. So, I would prdict that around 1-2 no-balls will be bowled in this match.
